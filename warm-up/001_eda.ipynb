# %% [markdown]
# ### First look into data from Kaggle competition "Warmup Round - March Machine Learning Mania 2023"
# https://www.kaggle.com/competitions/warmup-round-march-machine-learning-mania-2023

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import glob
import xgboost as xgb

# %%
for name in glob.glob("../data/*.csv"):
    print(name)
# Out:
# ../data\Cities.csv
# ../data\Conferences.csv
# ../data\MConferenceTourneyGames.csv
# ../data\MGameCities.csv
# ../data\MMasseyOrdinals.csv
# ../data\MNCAATourneyCompactResults.csv
# ../data\MNCAATourneyDetailedResults.csv
# ../data\MNCAATourneySeedRoundSlots.csv
# ../data\MNCAATourneySeeds.csv
# ../data\MNCAATourneySlots.csv
# ../data\MRegularSeasonCompactResults.csv
# ../data\MRegularSeasonDetailedResults.csv
# ../data\MSeasons.csv
# ../data\MSecondaryTourneyCompactResults.csv
# ../data\MSecondaryTourneyTeams.csv
# ../data\MTeamCoaches.csv
# ../data\MTeamConferences.csv
# ../data\MTeams.csv
# ../data\MTeamSpellings.csv
# ../data\SampleSubmissionWarmup.csv
# ../data\WGameCities.csv
# ../data\WNCAATourneyCompactResults.csv
# ../data\WNCAATourneyDetailedResults.csv
# ../data\WNCAATourneySeeds.csv
# ../data\WNCAATourneySlots.csv
# ../data\WRegularSeasonCompactResults.csv
# ../data\WRegularSeasonDetailedResults.csv
# ../data\WSeasons.csv
# ../data\WTeamConferences.csv
# ...

# %%
df = pd.read_csv('../data/Cities.csv')

# %%
df.describe()
# Out:
#             CityID
# count   472.000000
# mean   4240.847458
# std     142.509574
# min    4001.000000
# 25%    4118.750000
# 50%    4236.500000
# 75%    4355.250000
# max    4494.000000

# %%
df.head()
# Out:
#    CityID         City State
# 0    4001      Abilene    TX
# 1    4002        Akron    OH
# 2    4003       Albany    NY
# 3    4004  Albuquerque    NM
# 4    4005    Allentown    PA

# %%
df = {}
for name in glob.glob("../data/*.csv"):
#     print(name)
    print("\n")
    print(name.split('\\')[-1].split('.csv')[0])
    df[name.split('\\')[-1].split('.csv')[0]] = pd.read_csv(name)
#     print(df[name.split('\\')[-1].split('.csv')[0]].info())
#     print(df[name.split('\\')[-1].split('.csv')[0]].describe())
    print(df[name.split('\\')[-1].split('.csv')[0]].head())
# Out:
# Cities
#    CityID         City State
# 0    4001      Abilene    TX
# 1    4002        Akron    OH
# 2    4003       Albany    NY
# 3    4004  Albuquerque    NM
# 4    4005    Allentown    PA
#
#
# Conferences
#   ConfAbbrev                   Description
# 0      a_sun       Atlantic Sun Conference
# 1      a_ten        Atlantic 10 Conference
# 2        aac  American Athletic Conference
# 3        acc     Atlantic Coast Conference
# 4        aec       America East Conference
#
#
# MConferenceTourneyGames
#    Season ConfAbbrev  DayNum  WTeamID  LTeamID
# 0    2001      a_sun     121     1194     1144
# 1    2001      a_sun     121     1416     1240
# 2    2001      a_sun     122     1209     1194
# 3    2001      a_sun     122     1359     1239
# 4    2001      a_sun     122     1391     1273
#
#
# MGameCities
#    Season  DayNum  WTeamID  LTeamID   CRType  CityID
# 0    2010       7     1143     1293  Regular    4027
# 1    2010       7     1314     1198  Regular    4061
# ...

# %%
df['MRegularSeasonCompactResults'].head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT
# 0    1985      20     1228      81     1328      64    N      0
# 1    1985      25     1106      77     1354      70    H      0
# 2    1985      25     1112      63     1223      56    H      0
# 3    1985      25     1165      70     1432      54    H      0
# 4    1985      25     1192      86     1447      74    H      0

# %%
df2 = df['MRegularSeasonCompactResults']

# %%
df2.shape
# Out:
# (180189, 8)

# %%
df2.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT
# 0    1985      20     1228      81     1328      64    N      0
# 1    1985      25     1106      77     1354      70    H      0
# 2    1985      25     1112      63     1223      56    H      0
# 3    1985      25     1165      70     1432      54    H      0
# 4    1985      25     1192      86     1447      74    H      0

# %%
df2.WTeamID.value_counts()
# Out:
# 1181    984
# 1242    977
# 1246    921
# 1314    910
# 1112    910
#        ...
# 1477     10
# 1289      6
# 1118      6
# 1473      6
# 1327      3
# Name: WTeamID, Length: 377, dtype: int64

# %%
df2.LTeamID.value_counts()
# Out:
# 1152    821
# 1271    780
# 1363    754
# 1341    747
# 1224    727
#        ...
# 1473     16
# 1476     14
# 1477     13
# 1475     12
# 1474      9
# Name: LTeamID, Length: 377, dtype: int64
